# %% [markdown]
# # Prelude

# %%
import pandas
import numpy
import matplotlib
import seaborn

from matplotlib import pyplot
seaborn.set()

# %%
pyplot.rcParams['figure.figsize'] = (8, 3)

# %% [markdown]
# # Methodology

# %% [markdown]
# ## IoU Loss

# %%
baseline_unet_iou_scores = numpy.array([0.80655, 0.94167, 1.1333, 1.23879, 1.19409, 1.29541, 1.43649, 1.45572, 1.40763, 1.54757, 1.54512, 1.62514, 1.58909, 1.63719, 1.63433, 1.64935, 1.58962, 1.62392, 1.62088, 1.67552, 1.71471, 1.72858, 1.73372, 1.72914, 1.73151 ])
iou_losses = numpy.array([0.903226, 0.862487, 0.832877, 0.822896, 0.817632, 0.806295, 0.804603, 0.80014, 0.798781, 0.798066, 0.795254, 0.793733, 0.79203, 0.78845, 0.792284, 0.788268, 0.785956, 0.787199, 0.791855, 0.785417, 0.787246, 0.787823, 0.786971, 0.785136, 0.787325, 0.783794, 0.785055, 0.782013, 0.785518, 0.782308, 0.782611, 0.781255, 0.781072, 0.781851, 0.7853, 0.780929, 0.783086, 0.781517, 0.779642, 0.778878, 0.782677, 0.783255, 0.78309, 0.780256, 0.780035, 0.780735, 0.780806, 0.775432, 0.772472, 0.773583, 0.770995, 0.772044, 0.769659, 0.769719, 0.769187, 0.768391, 0.769838, 0.770961, 0.770082, 0.77048, 0.770077, 0.771954, 0.771162, 0.768977, 0.771425, 0.769284, 0.770863, 0.769544, 0.76905, 0.768746, 0.770411, 0.770582, 0.770766, 0.770748, 0.769898, 0.76981, 0.770325, 0.770739, 0.771567, 0.769891, 0.770854, 0.770224, 0.771502, 0.771427, 0.771017, 0.770579, 0.770496, 0.769344, 0.770561, 0.77213, 0.770367, 0.771119, 0.771582, 0.771158, 0.771643, 0.770531, 0.771362, 0.772447, 0.770834, 0.771295])

# %%
pyplot.title('IoU score on UNet model')
pyplot.xlabel('Epoch')
pyplot.ylabel('IoU score')

pyplot.plot(baseline_unet_iou_scores, label = 'Minimise CCE loss')
pyplot.plot(6 * (1 - iou_losses[:25]), label = 'Minimise IoU loss')
pyplot.legend()

pyplot.savefig('../cce_vs_iou_loss.png', dpi = 200, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # Gammas

# %%
gamma   = pandas.read_csv('gamma_losses.csv', index_col = 0)
nogamma = pandas.read_csv('nogamma_losses.csv', index_col = 0).loc[:gamma.shape[0]]
colors = seaborn.color_palette(None, 2)

# %%
pyplot.ylim((40000, 230000))

pyplot.plot(gamma['train'], color = colors[0], linestyle = '--', linewidth = 2)
pyplot.plot(gamma['val'], color = colors[0])

pyplot.plot(nogamma['train'], color = colors[1], linestyle = '--', linewidth = 2)
pyplot.plot(nogamma['val'], color = colors[1])

pyplot.plot([], color = colors[0], label = '$\\gamma = \\sqrt{\\frac{1}{10}}$')
pyplot.plot([], color = colors[1], label = '$\\gamma = 1$ (no change)')

pyplot.plot([], color = 'gray',  label = 'Validation loss')
pyplot.plot([], color = 'gray', linestyle = '--', linewidth = 2, label = 'Train loss')

pyplot.xlabel('Epochs')
pyplot.ylabel('CCE loss')

pyplot.vlines([10, 20, 30], 0, 1000000, color = 'gray', linestyle = 'dotted', linewidth = 1)

pyplot.legend()

pyplot.title('Categorical Cross-Entropy Loss of UNet classifiers')

pyplot.savefig('../gamma_vs_nogamma.png', dpi = 300, bbox_inches = 'tight', pad_inches = 0)
